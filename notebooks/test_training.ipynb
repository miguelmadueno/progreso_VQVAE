# %%
import sys
sys.path.append("../new_way")

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from api import vqvae_training

# %%
# %%time

vqvae_training(model_route=r"/export/usuarios01/icmora/deploymentVQVAE/deployment-VQVAE/ignore/results/training/try2", 
               data_route=r"/export/usuarios01/icmora/deploymentVQVAE/deployment-VQVAE/ignore/merged.csv",
               hyperparameters = {"num_epochs_vqvae":40, "train_batch_size":256}
)
# Out:
# Model set to train on GPU: 0 for model: a0_1767983784 started. Preparing data loaders.
#
# self.dataset.columns =
# array(['user', 'date_time', 'service', 'sleep_start', 'location_distance',
#        'location_time_home', 'sleep_duration', 'activity_walking',
#        'app_usage_total', 'location_clusters_count', 'steps_steps_total',
#        'weekend', 'practiced_sport', 'steps_0', 'steps_1', 'steps_2',
#        'steps_3', 'steps_4', 'steps_5', 'steps_6', 'steps_7', 'steps_8',
#        'steps_9', 'steps_10', 'steps_11', 'steps_12', 'steps_13',
#        'steps_14', 'steps_15', 'steps_16', 'steps_17', 'steps_18',
#        'steps_19', 'steps_20', 'steps_21', 'steps_22', 'steps_23',
#        'steps_24', 'steps_25', 'steps_26', 'steps_27', 'steps_28',
#        'steps_29', 'steps_30', 'steps_31', 'steps_32', 'steps_33',
#        'steps_34', 'steps_35', 'steps_36', 'steps_37', 'steps_38',
#        'steps_39', 'steps_40', 'steps_41', 'steps_42', 'steps_43',
# ...

# %%
# %%time

vqvae_training(model_route=r"/export/usuarios01/icmora/deploymentVQVAE/deployment-VQVAE/ignore/results/training/try2", 
               data_route=r"/export/usuarios01/icmora/deploymentVQVAE/deployment-VQVAE/ignore/data_test/daily_summary_DC.csv",
               hyperparameters = {"num_epochs_vqvae":1, "train_batch_size":512}
)
# Out:
# Model set to train on GPU: 0 for model: a0_1767650043 started. Preparing data loaders.
#
# self.dataset.columns =
# array(['user', 'date_time', 'service', 'sleep_start', 'location_distance',
#        'location_time_home', 'sleep_duration', 'activity_walking',
#        'app_usage_total', 'location_clusters_count', 'steps_steps_total',
#        'weekend', 'practiced_sport'], dtype=object)
#
# self.dataset.dtypes =
# user                                int64
# date_time                  datetime64[ns]
# service                            object
# sleep_start                       float64
# location_distance                 float64
# location_time_home                float64
# sleep_duration                    float64
# activity_walking                  float64
# app_usage_total                   float64
# location_clusters_count           float64
# steps_steps_total                 float64
# weekend                             int64
# practiced_sport                     int64
# ...

# %%
# %%time

vqvae_training(model_route="/export/usuarios01/icmora/deploymentVQVAE/api_test/results_finetune/fine_tune1", 
               data_route="~/data/eb2/daily_summary_eb2prod.csv",
               hyperparameters = {"num_epochs_vqvae":1, "train_batch_size":512}
)
# Out:
# /export/usuarios01/icmora/deploymentVQVAE/new_way/api_utils.py:144: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(original_data_path)
# Model set to train on GPU: 0 for model: a0_1760967503 started. Preparing data loaders.
#
# self.dataset.columns =
# array(['user', 'date_time', 'service', 'sleep_start', 'location_distance',
#        'location_time_home', 'sleep_duration', 'activity_walking',
#        'app_usage_total', 'location_clusters_count', 'steps_steps_total',
#        'weekend', 'practiced_sport'], dtype=object)
#
# self.dataset.dtypes =
# user                                int64
# date_time                  datetime64[ns]
# service                           float64
# sleep_start                       float64
# location_distance                 float64
# location_time_home                float64
# sleep_duration                    float64
# activity_walking                  float64
# ...
