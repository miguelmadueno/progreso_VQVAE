# %%
import sys
sys.path.append("../new_way")

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
from api import vqvae_training

# %%
# %%time

vqvae_training(model_route="/export/usuarios01/icmora/deploymentVQVAE-GitHub/uploadcode/vqvae-profiling/api_test/results_training/training_6", 
               data_route="~/data/eb2/daily_summary_eb2prod.csv",
               hyperparameters = {"num_epochs_vqvae":1, "train_batch_size":512}
)
# Out:
# /export/usuarios01/icmora/deploymentVQVAE-GitHub/uploadcode/vqvae-profiling/notebooks/../new_way/api_utils.py:144: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(original_data_path)
# Model set to train on GPU: 0 for model: a0_1762863456 started. Preparing data loaders.
#
# self.dataset.columns =
# array(['user', 'date_time', 'service', 'sleep_start', 'location_distance',
#        'location_time_home', 'sleep_duration', 'activity_walking',
#        'app_usage_total', 'location_clusters_count', 'steps_steps_total',
#        'weekend', 'practiced_sport'], dtype=object)
#
# self.dataset.dtypes =
# user                                int64
# date_time                  datetime64[ns]
# service                           float64
# sleep_start                       float64
# location_distance                 float64
# location_time_home                float64
# sleep_duration                    float64
# ...

# %%
# %%time

vqvae_training(model_route="/export/usuarios01/icmora/deploymentVQVAE/api_test/results_finetune/fine_tune1", 
               data_route="~/data/eb2/daily_summary_eb2prod.csv",
               hyperparameters = {"num_epochs_vqvae":1, "train_batch_size":512}
)
# Out:
# /export/usuarios01/icmora/deploymentVQVAE/new_way/api_utils.py:144: DtypeWarning: Columns (55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(original_data_path)
# Model set to train on GPU: 0 for model: a0_1760967503 started. Preparing data loaders.
#
# self.dataset.columns =
# array(['user', 'date_time', 'service', 'sleep_start', 'location_distance',
#        'location_time_home', 'sleep_duration', 'activity_walking',
#        'app_usage_total', 'location_clusters_count', 'steps_steps_total',
#        'weekend', 'practiced_sport'], dtype=object)
#
# self.dataset.dtypes =
# user                                int64
# date_time                  datetime64[ns]
# service                           float64
# sleep_start                       float64
# location_distance                 float64
# location_time_home                float64
# sleep_duration                    float64
# activity_walking                  float64
# ...
