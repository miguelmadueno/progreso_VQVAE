# %%
import sys
sys.path.append("../new_way/")

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from api import vqvae_inference

# %%
model_route= r"/export/usuarios01/icmora/deploymentVQVAE-GitHub/deployment-VQVAE/data/vqvae_a1_m_best.pt"
data_path=r"/export/usuarios01/icmora/deploymentVQVAE/api_test/one_patient/one_patient_info.csv"
results_folder_path = r"/export/usuarios01/icmora/deploymentVQVAE-GitHub/deployment-VQVAE/api_test/results_inference"

# %%
inference = vqvae_inference(model_route= model_route, device =  "cpu")
# Out:
# Model successfully loaded

# %%
print(inference.model)
print(inference.device)
# Out:
# VQVAE(
#   (encoder): Encoder(
#     (relu): ReLU()
#     (dropout): Dropout1d(p=0.5, inplace=False)
#     (intra_mask_1): Conv1d(10, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn_intra_mask_1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (intra_mask_2): Conv1d(10, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn_intra_mask_2): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (pre_mask): Sequential(
#       (0): Conv1d(10, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#       (1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv1d(10, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#       (4): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     )
#     (conv1): Conv1d(20, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(10, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv1d(20, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn3): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn4): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv1d(40, 60, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn5): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv1d(60, 80, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn6): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv_layers): Sequential(
#       (0): Conv1d(20, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#       (1): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Conv1d(10, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#       (4): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Conv1d(20, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#       (7): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Conv1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#       (10): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Conv1d(40, 60, kernel_size=(3,), stride=(1,), padding=(1,))
#       (13): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#       (15): Conv1d(60, 80, kernel_size=(3,), stride=(1,), padding=(1,))
#       (16): BatchNorm1d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (17): ReLU()
#     )
#   )
#   (decoder): Decoder(
#     (relu): ReLU()
#     (id): Identity()
#     (dropout): Dropout1d(p=0.5, inplace=False)
#     (deconv1): ConvTranspose1d(80, 60, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (deconv2): ConvTranspose1d(60, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (deconv3): ConvTranspose1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn3): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (deconv4): ConvTranspose1d(40, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn4): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (deconv5): ConvTranspose1d(20, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn5): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (deconv_layers): Sequential(
#       (0): ConvTranspose1d(80, 60, kernel_size=(3,), stride=(1,), padding=(1,))
#       (1): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): ConvTranspose1d(60, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#       (4): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): ConvTranspose1d(40, 40, kernel_size=(3,), stride=(1,), padding=(1,))
#       (7): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): ConvTranspose1d(40, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#       (10): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): ConvTranspose1d(20, 10, kernel_size=(3,), stride=(1,), padding=(1,))
#       (13): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): Identity()
#     )
#   )
#   (quantizer): Quantizer()
# )
# cpu

# %%
# %%time

inference.forward(data_path = data_path,
                  results_folder_path = results_folder_path,
)
# Out:
# Data successfully loaded
#
# Out of 1, 1 were kept, and 0 were discarded due to duplicated dates.
#
# [7844]
# Patient ID: 7844, sample shape: (30, 14)
# /export/usuarios01/icmora/envs/conda_envs/test1/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:1533: RuntimeWarning: All-NaN slice encountered
#   self.center_ = np.nanmedian(X, axis=0)
# /export/usuarios01/icmora/envs/conda_envs/test1/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/deploymentVQVAE-GitHub/deployment-VQVAE/notebooks/../new_way/api.py:162, in vqvae_inference.forward(self, data_path, results_folder_path)
#     159 inputs[(masks == 0) | (masks == 2)] = 0
#     161 # Forward pass
# --> 162 _, _, indices, embedding_info = self.model(inputs, masks_)
#     163 print("Forwarded Batch")
#     164 # Collect records per user
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/deploymentVQVAE-GitHub/deployment-VQVAE/notebooks/../new_way/vqvae_a.py:592, in VQVAE.forward(self, input, mask)
#     574 """
#     575 Forward pass of the VQVAE model. Encodes the input, quantizes the latent representation,
#     576 and decodes it to reconstruct the input.
#    (...)
#     588         embedding_info (np.ndarray): Structured array containing embedding ranking and distance info.
#     589 """
#     591 # Encode the input signal
# --> 592 encoded = self.encoder(input, mask if self.mask_flag in [1, 2] else None)
#     594 # Quantize the encoded representation
#     595 quantized, diff, indices, embedding_info = self.quantizer(encoded.permute(0, 2, 1))
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/deploymentVQVAE-GitHub/deployment-VQVAE/notebooks/../new_way/vqvae_a.py:320, in Encoder.forward(self, input, mask)
#     318 if self.mask_flag in [1, 2]:
#     319     for layer in self.pre_mask:
# --> 320         mask = layer(mask)
#     322 # Concatenate input and mask if masking is enabled
#     323 if mask is not None and self.mask_flag in [1, 2]:
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/conv.py:310, in Conv1d.forward(self, input)
#     309 def forward(self, input: Tensor) -> Tensor:
# --> 310     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/envs/conda_envs/test1/lib/python3.10/site-packages/torch/nn/modules/conv.py:306, in Conv1d._conv_forward(self, input, weight, bias)
#     302 if self.padding_mode != 'zeros':
#     303     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     304                     weight, bias, self.stride,
#     305                     _single(0), self.dilation, self.groups)
# --> 306 return F.conv1d(input, weight, bias, self.stride,
#     307                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [10, 10, 3], expected input[1, 11, 30] to have 10 channels, but got 11 channels instead

# %%
# %%time

inference.device = "cuda"
inference.forward(data_path = data_path,
                  results_folder_path = results_folder_path,
)
# Out:
# Data successfully loaded
#
# Out of 1, 1 were kept, and 0 were discarded due to duplicated dates.
#
# [7844]
# Patient ID: 7844, sample shape: (30, 13)
# /export/usuarios01/icmora/envs/conda_envs/test1/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:1533: RuntimeWarning: All-NaN slice encountered
#   self.center_ = np.nanmedian(X, axis=0)
# /export/usuarios01/icmora/envs/conda_envs/test1/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# Forwarded Batch
# Dataset saved to: /export/usuarios01/icmora/deploymentVQVAE-GitHub/uploadcode/vqvae-profiling/removeee/vqvae_a2_m_best_one_patient_info_20251111_132312/one_patient_info.pkl
# CPU times: user 226 ms, sys: 161 ms, total: 387 ms
# Wall time: 395 ms
#    user                                            indices
# 0  7844  [33, 100, 33, 229, 47, 47, 47, 47, 47, 47, 47,...
